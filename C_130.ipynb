# %% [markdown]
# <a href="https://colab.research.google.com/github/Xander50/C-130/blob/main/C_130.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/procodingclass/PRO-NASA-Exoplanet-Processed-Data
# Out:
# fatal: destination path 'PRO-NASA-Exoplanet-Processed-Data' already exists and is not an empty directory.

# %%
import pandas as pd
final_planet_df=pd.read_csv("/content/PRO-NASA-Exoplanet-Processed-Data/final.csv")
print(final_planet_df.shape)
# Out:
# (4284, 85)

# %%
final_planet_df.head(15)
# Out:
#                             name  light_years_from_earth     planet_mass  \
# 0           11 Comae Berenices b                   305.0   19.4 Jupiters
# 1             11 Ursae Minoris b                   410.0  14.74 Jupiters
# 2                14 Andromedae b                   247.0    4.8 Jupiters
# 3                  14 Herculis b                    59.0   4.66 Jupiters
# 4                   16 Cygni B b                    69.0   1.78 Jupiters
# 5                  18 Delphini b                   249.0   10.3 Jupiters
# 6        1RXS J160929.1-210524 b                   473.0      8 Jupiters
# 7                    24 Bootis b                   314.0   0.91 Jupiters
# 8                 24 Sextantis b                   236.0   1.99 Jupiters
# 9                 24 Sextantis c                   236.0   0.86 Jupiters
# 10  2MASS J01033563-5515561 AB b                   154.0     13 Jupiters
# 11     2MASS J01225093-2439505 b                   117.0   24.5 Jupiters
# ...

# %%
final_planet_df.to_csv("main.csv")

# %%
from google.colab import files
files.download("main.csv")
